# %%
import requests as rq
import json
from sqlalchemy import create_engine as ce
import pandas as pd

# %%
data = rq.get('https://swapi.dev/api/people/?Page=9').json()
data.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
data1 = rq.get('https://swapi.dev/api/people/20')
data1
# Out:
# <Response [200]>

# %%
#print(type(data['results']))
data1.json().keys()
data_ = data1.json()
data_
# Out:
# {'name': 'Yoda',
#  'height': '66',
#  'mass': '17',
#  'hair_color': 'white',
#  'skin_color': 'green',
#  'eye_color': 'brown',
#  'birth_year': '896BBY',
#  'gender': 'male',
#  'homeworld': 'https://swapi.dev/api/planets/28/',
#  'films': ['https://swapi.dev/api/films/2/',
#   'https://swapi.dev/api/films/3/',
#   'https://swapi.dev/api/films/4/',
#   'https://swapi.dev/api/films/5/',
#   'https://swapi.dev/api/films/6/'],
#  'species': ['https://swapi.dev/api/species/6/'],
#  'vehicles': [],
#  'starships': [],
#  'created': '2014-12-15T12:26:01.042000Z',
#  'edited': '2014-12-20T21:17:50.345000Z',
#  'url': 'https://swapi.dev/api/people/20/'}

# %%
page_num = 1
sw_data = []
has_next = True

while has_next:
    data = rq.get('https://swapi.dev/api/people/?Page='+ str(page_num)).json()
    print('this is page ' + str(page_num) + ' with '+ str(len(data['results'])) + ' entries')
    sw_data.extend(data['results'])
    has_next = len(sw_data) <= data['count']
    page_num +=1
# Out:
# this is page 1 with 10 entries
# this is page 2 with 10 entries
# this is page 3 with 10 entries
# this is page 4 with 10 entries
# this is page 5 with 10 entries
# this is page 6 with 10 entries
# this is page 7 with 10 entries
# this is page 8 with 10 entries
# this is page 9 with 10 entries

# %%
page_num = 1
sw_data = []
has_next = True

while has_next:
    data = rq.get('https://swapi.dev/api/people/?Page='+ str(page_num)).json()
    print('Treated page num ' +str(page_num))
    sw_data.extend(data['results'])
    has_next = len(sw_data) <= data['count']
    page_num +=1

# %%
len(sw_data)
# Out:
# 90

# %%
sw_norm = pd.json_normalize(sw_data)
sw_norm
# Out:
#                   name height mass     hair_color   skin_color  eye_color  \
# 0       Luke Skywalker    172   77          blond         fair       blue
# 1                C-3PO    167   75            n/a         gold     yellow
# 2                R2-D2     96   32            n/a  white, blue        red
# 3          Darth Vader    202  136           none        white     yellow
# 4          Leia Organa    150   49          brown        light      brown
# ..                 ...    ...  ...            ...          ...        ...
# 85           Owen Lars    178  120    brown, grey        light       blue
# 86  Beru Whitesun lars    165   75          brown        light       blue
# 87               R5-D4     97   32            n/a   white, red        red
# 88   Biggs Darklighter    183   84          black        light      brown
# 89      Obi-Wan Kenobi    182   77  auburn, white         fair  blue-gray
#
#    birth_year  gender                          homeworld  \
# ...
