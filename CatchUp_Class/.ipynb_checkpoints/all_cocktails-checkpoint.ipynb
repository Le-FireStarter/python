# %%
import requests
import json
import pandas as pd

# %%
link = 'https://www.thecocktaildb.com/api/json/v1/1/search.php?f=a'
drinks = requests.get(link)

# %%
drinks.json()
# Out:
# {'drinks': [{'idDrink': '17222',
#    'strDrink': 'A1',
#    'strDrinkAlternate': None,
#    'strTags': None,
#    'strVideo': None,
#    'strCategory': 'Cocktail',
#    'strIBA': None,
#    'strAlcoholic': 'Alcoholic',
#    'strGlass': 'Cocktail glass',
#    'strInstructions': 'Pour all ingredients into a cocktail shaker, mix and serve over ice into a chilled glass.',
#    'strInstructionsES': 'Vierta todos los ingredientes en una coctelera, mezcle y sirva con hielo en un vaso frío.',
#    'strInstructionsDE': 'Alle Zutaten in einen Cocktailshaker geben, mischen und über Eis in ein gekühltes Glas servieren.',
#    'strInstructionsFR': None,
#    'strInstructionsIT': 'Versare tutti gli ingredienti in uno shaker, mescolare e servire con ghiaccio in un bicchiere freddo.',
#    'strInstructionsZH-HANS': None,
#    'strInstructionsZH-HANT': None,
#    'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/2x8thr1504816928.jpg',
#    'strIngredient1': 'Gin',
# ...

# %%
all = json.loads(drinks.text)['drinks']
all
# Out:
# [{'idDrink': '17222',
#   'strDrink': 'A1',
#   'strDrinkAlternate': None,
#   'strTags': None,
#   'strVideo': None,
#   'strCategory': 'Cocktail',
#   'strIBA': None,
#   'strAlcoholic': 'Alcoholic',
#   'strGlass': 'Cocktail glass',
#   'strInstructions': 'Pour all ingredients into a cocktail shaker, mix and serve over ice into a chilled glass.',
#   'strInstructionsES': 'Vierta todos los ingredientes en una coctelera, mezcle y sirva con hielo en un vaso frío.',
#   'strInstructionsDE': 'Alle Zutaten in einen Cocktailshaker geben, mischen und über Eis in ein gekühltes Glas servieren.',
#   'strInstructionsFR': None,
#   'strInstructionsIT': 'Versare tutti gli ingredienti in uno shaker, mescolare e servire con ghiaccio in un bicchiere freddo.',
#   'strInstructionsZH-HANS': None,
#   'strInstructionsZH-HANT': None,
#   'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/2x8thr1504816928.jpg',
#   'strIngredient1': 'Gin',
#   'strIngredient2': 'Grand Marnier',
# ...

# %%
frame = pd.DataFrame(all)
frame.head(10)
# Out:
#   idDrink strDrink strDrinkAlternate            strTags strVideo  \
# 0   17222       A1              None               None     None
# 1   13501      ABC              None               None     None
# 2   17225      Ace              None               None     None
# 3   17837     Adam              None  Alcoholic,Holiday     None
# 4   13938     AT&T              None               None     None
# 5   14610     ACID              None               None     None
# 6   17833    A. J.              None               None     None
# 7   17839   Affair              None               None     None
# 8   15106   Apello              None               None     None
# 9   15266   Avalon              None               None     None
#
#       strCategory strIBA   strAlcoholic        strGlass  \
# 0        Cocktail   None      Alcoholic  Cocktail glass
# 1            Shot   None      Alcoholic      Shot glass
# 2        Cocktail   None      Alcoholic   Martini Glass
# ...
